# %% [markdown]
# # Data Visualizations - Top Indian Places to Visit
#
# Comprehensive visualizations of the Indian places dataset including distributions, comparisons, and geographic insights.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

df = pd.read_csv('../data/Top Indian Places to Visit.csv')
print("Dataset loaded successfully!")
print(f"Dataset shape: {df.shape}")

# %% [markdown]
# ## 1. Google Review Ratings Distribution

# %%
fig, ax = plt.subplots(figsize=(10, 6))
plt.hist(df['Google review rating'], bins=20, color='purple', edgecolor='black', alpha=0.7)
plt.xlabel('Google Review Rating', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Google Review Ratings', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Entrance Fee Distribution

# %%
fig, ax = plt.subplots(figsize=(10, 6))
plt.hist(df['Entrance Fee in INR'], bins=30, color='coral', edgecolor='black', alpha=0.7)
plt.xlabel('Entrance Fee (INR)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Entrance Fees', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Time Needed to Visit Distribution

# %%
fig, ax = plt.subplots(figsize=(10, 6))
plt.hist(df['time needed to visit in hrs'], bins=25, color='lightgreen', edgecolor='black', alpha=0.7)
plt.xlabel('Time Needed (hours)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Time Needed to Visit Places', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Top 15 Places by Number of Google Reviews

# %%
top_reviews = df.nlargest(15, 'Number of google review in lakhs')[['Name', 'Number of google review in lakhs']].sort_values('Number of google review in lakhs')
fig, ax = plt.subplots(figsize=(12, 8))
plt.barh(top_reviews['Name'], top_reviews['Number of google review in lakhs'], color='skyblue', edgecolor='black')
plt.xlabel('Number of Reviews (in lakhs)', fontsize=12)
plt.title('Top 15 Places by Number of Google Reviews', fontsize=14, fontweight='bold')
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Places Distribution by Zone

# %%
zone_counts = df['Zone'].value_counts().sort_values()
fig, ax = plt.subplots(figsize=(10, 6))
plt.barh(zone_counts.index, zone_counts.values, color='mediumpurple', edgecolor='black')
plt.xlabel('Number of Places', fontsize=12)
plt.title('Distribution of Places by Zone', fontsize=14, fontweight='bold')
plt.grid(axis='x', alpha=0.3)
for i, v in enumerate(zone_counts.values):
    plt.text(v + 0.3, i, str(v), va='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Top 10 Places by Type

# %%
type_counts = df['Type'].value_counts().head(10)
fig, ax = plt.subplots(figsize=(12, 6))
bars = plt.bar(range(len(type_counts)), type_counts.values, color='teal', edgecolor='black', alpha=0.7)
plt.xticks(range(len(type_counts)), type_counts.index, rotation=45, ha='right')
plt.ylabel('Number of Places', fontsize=12)
plt.title('Top 10 Place Types by Count', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)
for i, v in enumerate(type_counts.values):
    plt.text(i, v + 0.5, str(v), ha='center', va='bottom')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Best Time to Visit Distribution

# %%
best_time = df['Best Time to visit'].value_counts()
fig, ax = plt.subplots(figsize=(10, 6))
colors_time = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA07A', '#98D8C8']
bars = plt.bar(best_time.index, best_time.values, color=colors_time, edgecolor='black', alpha=0.8)
plt.ylabel('Number of Places', fontsize=12)
plt.title('Best Time to Visit Distribution', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
            f'{int(height)}', ha='center', va='bottom')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Scatter Plot: Google Rating vs Number of Reviews

# %%
fig, ax = plt.subplots(figsize=(10, 6))
scatter = plt.scatter(df['Google review rating'], df['Number of google review in lakhs'], 
                     c=df['Entrance Fee in INR'], cmap='viridis', s=100, alpha=0.6, edgecolors='black')
plt.xlabel('Google Review Rating', fontsize=12)
plt.ylabel('Number of Reviews (in lakhs)', fontsize=12)
plt.title('Google Rating vs Number of Reviews', fontsize=14, fontweight='bold')
cbar = plt.colorbar(scatter)
cbar.set_label('Entrance Fee (INR)', fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Box Plot: Google Rating by Place Type (Top 8 Types)

# %%
top_8_types = df['Type'].value_counts().head(8).index
df_top_types = df[df['Type'].isin(top_8_types)]

fig, ax = plt.subplots(figsize=(12, 6))
sns.boxplot(data=df_top_types, x='Type', y='Google review rating', palette='Set2')
plt.xlabel('Place Type', fontsize=12)
plt.ylabel('Google Review Rating', fontsize=12)
plt.title('Distribution of Ratings by Top 8 Place Types', fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Top 10 States by Number of Places

# %%
top_states = df['State'].value_counts().head(10).sort_values()
fig, ax = plt.subplots(figsize=(12, 7))
colors_states = plt.cm.Spectral(np.linspace(0, 1, len(top_states)))
plt.barh(top_states.index, top_states.values, color=colors_states, edgecolor='black')
plt.xlabel('Number of Places', fontsize=12)
plt.title('Top 10 States by Number of Places', fontsize=14, fontweight='bold')
plt.grid(axis='x', alpha=0.3)
for i, v in enumerate(top_states.values):
    plt.text(v + 0.3, i, str(v), va='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 11. Average Entrance Fee by Significance Category

# %%
avg_fee_by_sig = df.groupby('Significance')['Entrance Fee in INR'].mean().sort_values(ascending=False)
fig, ax = plt.subplots(figsize=(11, 6))
bars = plt.bar(range(len(avg_fee_by_sig)), avg_fee_by_sig.values, 
               color='gold', edgecolor='black', alpha=0.8)
plt.xticks(range(len(avg_fee_by_sig)), avg_fee_by_sig.index, rotation=45, ha='right')
plt.ylabel('Average Entrance Fee (INR)', fontsize=12)
plt.title('Average Entrance Fee by Significance Category', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)
for i, v in enumerate(avg_fee_by_sig.values):
    plt.text(i, v + 2, f'₹{v:.0f}', ha='center', va='bottom', fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 12. Average Rating by Zone

# %%
avg_rating_by_zone = df.groupby('Zone')['Google review rating'].mean().sort_values()
fig, ax = plt.subplots(figsize=(10, 6))
bars = plt.barh(avg_rating_by_zone.index, avg_rating_by_zone.values, color='lightcoral', edgecolor='black')
plt.xlabel('Average Google Review Rating', fontsize=12)
plt.title('Average Google Review Rating by Zone', fontsize=14, fontweight='bold')
plt.xlim(4.0, 4.6)
for i, v in enumerate(avg_rating_by_zone.values):
    plt.text(v + 0.01, i, f'{v:.2f}', va='center')
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 13. Entrance Fee vs Time Needed (Scatter Plot)

# %%
fig, ax = plt.subplots(figsize=(11, 7))
scatter = plt.scatter(df['Entrance Fee in INR'], df['time needed to visit in hrs'], 
                     c=df['Google review rating'], cmap='plasma', s=150, alpha=0.6, edgecolors='black', linewidth=0.5)
plt.xlabel('Entrance Fee (INR)', fontsize=12)
plt.ylabel('Time Needed to Visit (hours)', fontsize=12)
plt.title('Relationship: Entrance Fee vs Time Needed to Visit', fontsize=14, fontweight='bold')
cbar = plt.colorbar(scatter)
cbar.set_label('Google Review Rating', fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 14. Free vs Paid Places Distribution

# %%
free_paid = df['Entrance Fee in INR'].apply(lambda x: 'Free' if x == 0 else 'Paid').value_counts()
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Pie chart
colors_fp = ['#90EE90', '#FFB6C1']
ax1.pie(free_paid.values, labels=free_paid.index, autopct='%1.1f%%', colors=colors_fp, 
        startangle=90, textprops={'fontsize': 12, 'weight': 'bold'})
ax1.set_title('Free vs Paid Places Distribution', fontsize=12, fontweight='bold')

# Bar chart
ax2.bar(free_paid.index, free_paid.values, color=colors_fp, edgecolor='black', alpha=0.8)
ax2.set_ylabel('Number of Places', fontsize=11)
ax2.set_title('Count: Free vs Paid Places', fontsize=12, fontweight='bold')
ax2.grid(axis='y', alpha=0.3)
for i, v in enumerate(free_paid.values):
    ax2.text(i, v + 2, str(v), ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()

print(f"Free Places: {free_paid['Free']}")
print(f"Paid Places: {free_paid['Paid']}")

# %% [markdown]
# ## 15. Average Time Needed by Zone

# %%
avg_time_by_zone = df.groupby('Zone')['time needed to visit in hrs'].mean().sort_values(ascending=False)
fig, ax = plt.subplots(figsize=(10, 6))
bars = plt.bar(range(len(avg_time_by_zone)), avg_time_by_zone.values, 
               color='orange', edgecolor='black', alpha=0.8)
plt.xticks(range(len(avg_time_by_zone)), avg_time_by_zone.index, rotation=45, ha='right')
plt.ylabel('Average Time (hours)', fontsize=12)
plt.title('Average Time Needed to Visit by Zone', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)
for i, v in enumerate(avg_time_by_zone.values):
    plt.text(i, v + 0.05, f'{v:.2f}h', ha='center', va='bottom', fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 16. Airport Availability by Zone

# %%
airport_by_zone = df[df['Airport with 50km Radius'] == 'Yes'].groupby('Zone').size()
no_airport = df[df['Airport with 50km Radius'] == 'No'].groupby('Zone').size()

fig, ax = plt.subplots(figsize=(10, 6))
x = np.arange(len(airport_by_zone))
width = 0.35

bars1 = plt.bar(x - width/2, airport_by_zone.values, width, label='With Airport', color='skyblue', edgecolor='black')
bars2 = plt.bar(x + width/2, no_airport.values, width, label='No Airport', color='salmon', edgecolor='black')

plt.xlabel('Zone', fontsize=12)
plt.ylabel('Number of Places', fontsize=12)
plt.title('Airport Availability (50km radius) by Zone', fontsize=14, fontweight='bold')
plt.xticks(x, airport_by_zone.index, rotation=45, ha='right')
plt.legend(fontsize=11)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 17. Weekly Off Day Distribution

# %%
weekly_off = df['Weekly Off'].value_counts()
fig, ax = plt.subplots(figsize=(11, 6))
colors_wo = plt.cm.Set3(np.linspace(0, 1, len(weekly_off)))
bars = plt.bar(range(len(weekly_off)), weekly_off.values, color=colors_wo, edgecolor='black', alpha=0.8)
plt.xticks(range(len(weekly_off)), weekly_off.index, rotation=45, ha='right')
plt.ylabel('Number of Places', fontsize=12)
plt.title('Weekly Off Day Distribution', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)
for i, v in enumerate(weekly_off.values):
    plt.text(i, v + 2, str(v), ha='center', va='bottom', fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 18. Average Rating by Best Time to Visit

# %%
avg_rating_by_time = df.groupby('Best Time to visit')['Google review rating'].mean().sort_values(ascending=False)
fig, ax = plt.subplots(figsize=(11, 6))
bars = plt.bar(range(len(avg_rating_by_time)), avg_rating_by_time.values, 
               color='lightsteelblue', edgecolor='black', alpha=0.8)
plt.xticks(range(len(avg_rating_by_time)), avg_rating_by_time.index, fontsize=11)
plt.ylabel('Average Google Review Rating', fontsize=12)
plt.title('Average Google Review Rating by Best Time to Visit', fontsize=14, fontweight='bold')
plt.ylim(4.0, 4.6)
plt.grid(axis='y', alpha=0.3)
for i, v in enumerate(avg_rating_by_time.values):
    plt.text(i, v + 0.01, f'{v:.2f}', ha='center', va='bottom', fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 19. Establishment Year Distribution

# %%
df_est = df[df['Establishment Year'] != 'Unknown'].copy()
df_est['Establishment Year'] = pd.to_numeric(df_est['Establishment Year'], errors='coerce')
df_est = df_est.dropna(subset=['Establishment Year'])

fig, ax = plt.subplots(figsize=(13, 6))
plt.hist(df_est['Establishment Year'], bins=30, color='mediumpurple', edgecolor='black', alpha=0.7)
plt.xlabel('Establishment Year', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Place Establishment Years', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

print(f"Oldest Place: {int(df_est['Establishment Year'].min())}")
print(f"Newest Place: {int(df_est['Establishment Year'].max())}")
print(f"Median Year: {int(df_est['Establishment Year'].median())}")

# %% [markdown]
# ## 20. Average Number of Reviews by Significance

# %%
avg_reviews_by_sig = df.groupby('Significance')['Number of google review in lakhs'].mean().sort_values(ascending=False)
fig, ax = plt.subplots(figsize=(11, 6))
bars = plt.bar(range(len(avg_reviews_by_sig)), avg_reviews_by_sig.values, 
               color='lightseagreen', edgecolor='black', alpha=0.8)
plt.xticks(range(len(avg_reviews_by_sig)), avg_reviews_by_sig.index, rotation=45, ha='right')
plt.ylabel('Average Number of Reviews (in lakhs)', fontsize=12)
plt.title('Average Number of Reviews by Significance Category', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)
for i, v in enumerate(avg_reviews_by_sig.values):
    plt.text(i, v + 0.05, f'{v:.2f}', ha='center', va='bottom', fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 21. Multi-Metric Dashboard: Zone vs Significance

# %%
pivot_rating = df.pivot_table(values='Google review rating', index='Zone', columns='Significance', aggfunc='mean')

fig, axes = plt.subplots(1, 2, figsize=(15, 10))

# Heatmap: Average Time Needed
pivot_time = df.pivot_table(values='time needed to visit in hrs', index='Zone', columns='Significance', aggfunc='mean')
sns.heatmap(pivot_time, annot=True, fmt='.1f', cmap='Blues', ax=axes[0],
            cbar_kws={'label': 'Avg Time (hrs)'})
axes[0].set_title('Average Time Needed by Zone & Significance', fontweight='bold', fontsize=11)

# Heatmap: Count of Places
pivot_count = df.pivot_table(values='Name', index='Zone', columns='Significance', aggfunc='count')
sns.heatmap(pivot_count, annot=True, fmt='g', cmap='Purples', ax=axes[1],
            cbar_kws={'label': 'Count'})
axes[1].set_title('Number of Places by Zone & Significance', fontweight='bold', fontsize=11)

plt.suptitle('Multi-Metric Analysis Dashboard: Zone vs Significance', 
             fontsize=14, fontweight='bold', y=1.00)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Key Insights from Exploratory Analysis
#
# ### Geographic Distribution
# - Dataset covers all major zones of India with comprehensive regional representation
# - Coastal and metropolitan zones have higher concentration of tourist destinations
#
# ### Quality Metrics
# - Most places have ratings between 4.0-4.7, indicating generally positive visitor experiences
# - Highly reviewed places correlate with major tourist attractions and historical monuments
#
# ### Visitor Experience
# - Average visit duration varies by place type: 1-5 hours being most common
# - Free attractions account for a significant portion but many premium places exist
# - DSLR permission positively impacts tourist destinations
#
# ### Accessibility
# - Most places have airport connectivity within 50km radius
# - Weekly off patterns reflect operational schedules and cultural significance
# - Best visit times vary - morning, afternoon, evening, and seasonal recommendations
#
# ### Economic Patterns
# - Entrance fees range from free to several hundred INR
# - Significance and place type influence pricing strategies
# - Religious and historical sites tend to have varying fee structures
#
# ### Data Quality
# - Comprehensive dataset with minimal missing values
# - Consistent categorization across geographical regions
# - Strong correlation between ratings and number of reviews

# %% [markdown]
# ## Summary
#
# This visualization notebook provides comprehensive insights into the Indian places dataset including:
#
# - **Distribution Analysis**: Ratings, entrance fees, and visit duration patterns
# - **Popularity Metrics**: Top-rated and most-reviewed places
# - **Geographic Insights**: Distribution across zones and states
# - **Category Analysis**: Types and significance of places
# - **Facility Features**: DSLR permissions and best visit times
# - **Correlation Analysis**: Relationships between different numerical features
#
# All visualizations help understand visitor preferences, pricing patterns, and geographic coverage of tourist destinations in India.
